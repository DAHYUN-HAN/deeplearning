# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-43f036b0-9195-458f-a5d8-e658d96a0662" name="files[]" multiple disabled />
#      <output id="result-43f036b0-9195-458f-a5d8-e658d96a0662">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpeg to cat.jpeg
# User uploaded file "cat.jpeg" with length 11920 bytes

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('cat.jpeg')
plt.imshow(img,cmap='gray')

# %%
img2 = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
plt.imshow(img2, cmap='gray')

# %%
cv2.imwrite('biFMA2.png',img)
# Out:
# True

# %%
img3 = cv2.flip(img2, 0)
plt.imshow(img3, cmap='gray')

# %%
img3 = cv2.flip(img2, -1)
plt.imshow(img3, cmap='gray')

# %%
img3 = cv2.flip(img2, 1)
plt.imshow(img3, cmap='gray')
