# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-73ba39f5-ef6d-4cc2-a97d-072c16032bcf" name="files[]" multiple disabled />
#      <output id="result-73ba39f5-ef6d-4cc2-a97d-072c16032bcf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpeg to cat.jpeg
# User uploaded file "cat.jpeg" with length 11920 bytes

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('cat.jpeg')
plt.imshow(img,cmap='gray')

# %%
gauss_blur = cv2.GaussianBlur(img,(21,21),0)
plt.imshow(gauss_blur, cmap='gray')
